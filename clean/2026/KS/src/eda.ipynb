# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../data/output/ks_index.csv")
    return df 


df = read_tbl()

df
# Out:
#        person_nbr           full_name first_name middle_name     last_name  \
# 8           10036       Steven Martin     Steven         NaN        Martin
# 167          1086      Jeffrey Bender    Jeffrey         NaN        Bender
# 482         12241       Steven Parker     Steven         NaN        Parker
# 588         12679    Chester Pinkston    Chester         NaN      Pinkston
# 876         14255  David Schoenberger      David         NaN  Schoenberger
# 1230        16160       Michael Thode    Michael         NaN         Thode
# 1337        16627        Robert Unruh     Robert         NaN         Unruh
# 20772         351      Jeffery Andres    Jeffery         NaN        Andres
# 22490        4782       Thomas Fatkin     Thomas         NaN        Fatkin
# 22772        6089        Thomas Grote     Thomas         NaN         Grote
# 23257        8481     Ronald Kendrick     Ronald         NaN      Kendrick
# ...
