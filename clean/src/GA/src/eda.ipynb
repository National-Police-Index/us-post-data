# %%
import pandas as pd

# %%
def read_agency():
    df = pd.read_csv("../data/input/5-10-2024/officer_sanctions.csv")
    return df


df = read_agency()

df
# Out:
#              CASE     OKEY                       NAME  \
# 0      0011400218  O239177               AARON ASHLEY
# 1      0045701195  O061330             AARON AUDREY R
# 2      0042591017  O152547           AARON JONATHAN B
# 3      0005801011  O152547           AARON JONATHAN B
# 4      0005801011  O152547           AARON JONATHAN B
# ...           ...      ...                        ...
# 44445  0067591121  O240210  ZUBERNIS CHRISTIAN EDWARD
# 44446  0022790215  O047667            ZWEBEN RONALD J
# 44447  0027500102  O047667            ZWEBEN RONALD J
# 44448  0054361007  O133176          ZWIERKO MICHAEL R
# 44449  0054361007  O133176          ZWIERKO MICHAEL R
#
#                                 SANCTION        DATE
# 0                    PROBATION 24 MONTHS  2019-01-08
# 1               ADMINISTRATIVE DISMISSAL  1996-05-09
# 2                              NO ACTION  2018-10-12
# 3                    PROBATION 24 MONTHS  2013-08-14
# ...
