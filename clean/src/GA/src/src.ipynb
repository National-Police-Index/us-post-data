# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../FL/data/input/fl-2023-original-agencies.csv", on_bad_lines="skip")
    return df

df = read_tbl()

df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[50], line 5
#       2     df = pd.read_csv("../../FL/data/input/fl-2023-original-agencies.csv", on_bad_lines="skip")
#       3     return df
# ----> 5 df = read_tbl()
#       7 df
#
# Cell In[50], line 2, in read_tbl()
#       1 def read_tbl():
# ----> 2     df = pd.read_csv("../../FL/data/input/fl-2023-original-agencies.csv", on_bad_lines="skip")
#       3     return df
#
# ...

# %%
# def read_tbl():
#     df = pd.read_csv("../data/output/georgia_index.csv")
#     return df

# def rename_cols(df):
#     df = df.rename(columns={"employment_status": "separation_reason",
#                             "agcy_name": "agency_name"})
#     return df


# def clean_sep_reason(df):
#     df.loc[:, "separation_reason"] = (df.separation_reason
#                                       .str.lower()
#                                       .str.strip()
#                                       .str.replace(r"demotion \(disciplinary\)", "disciplinary demotion", regex=True)
#                                       .str.replace(r"demotion \(voluntary or administrative\)", "voluntary or administrative demotion", regex=True)
#                                       .str.replace(r"^zz$", "", regex=True)
#                                       .str.replace(r"^yankee$", "", regex=True)
#                                       .str.replace(r"resigned w\/o proper notice", "resigned without proper notice", regex=True)
#                                       .str.title()
                                    
#     )
#     return df 

# def strip_agency_num(df):
#     df.loc[:, "agency_number"] = df.agency_name.str.replace(r"^G(\w+)(.+)", r"G\1", regex=True)
#     return df 

# def clean_agency_name(df):
#     df.loc[:, "agency_name"] = (df.agency_name
#                                 .str.lower()
#                                 .str.replace(r"^g(\w+)(.+)", r"\2", regex=True)
#                                 .str.strip()
#                                 .str.replace(r"d\.p\.s\.?", "department of public safety", regex=True)
#                                 .str.replace(r"dept\.?", "department", regex=True)
#                                 .str.replace(r"sheriffs", "sheriff's", regex=False)
#                                 .str.replace(r" co\.? ", " county ", regex=True)
#                                 .str.replace(r"\bga\.?\b", "georgia", regex=True)
#                                 .str.replace(r"juv\.justice", "juvenile justice", regex=True)
#     )

#     df = df[~((df.agency_name.str.lower().str.contains(r"fire")))]
#     return df 

# df = read_tbl()

# df = df.pipe(rename_cols).pipe(clean_sep_reason).pipe(strip_agency_num).pipe(clean_agency_name)


# # First, identify person_nbrs that have at least one "terminated" row
# terminated_persons = df[df.separation_reason.fillna("").str.lower().str.contains(r"terminated")]['person_nbr'].unique()

# # Then, get all rows for those persons who also have multiple rows
# df = df[df['person_nbr'].isin(terminated_persons)].groupby('person_nbr').filter(lambda x: len(x) > 1)

# df

# %%
# df.to_csv("../../../../download/data/georgia/georgia_index.csv", index=False)
