# %%
import pandas as pd

# %%
def read_npi():
    df = pd.read_csv("../data/input/california_npi_output.csv")
    return df

def read_lear():
    df = pd.read_csv("../data/input/lear_input.csv", sep="\t")
    return df 

def filter_state(df):
    df = df[df.STATE.str.contains(r"^CA$")]
    return df 

def fix_col_name(df):
    df = df.rename(columns={"NAME": "agency_name"})
    return df 

def normalize_npi(df):
    df.loc[:, "agency_name"] = (df.agency_name
                                .str.lower()
                                .str.strip()
                                .str.replace(r" pd$", " police department", regex=True)
                                .str.replace(r"co s[do]", "county sheriff's office", regex=True)
                                .str.replace(r" dps", " department of public safety", regex=True)
                                .str.replace(r"^ca ", "california ", regex=True)
                                .str.replace(r" co\b", " county", regex=True)
                                .str.replace(r"county(.+)coroner", r"county sheriff's office", regex=True)
                                .str.replace(r"county so$", "county sheriff's office", regex=True)
    )
  
    return df


def normalize_lear(df):
    df.loc[:, "agency_name"] = (df.agency_name
                                .str.lower()
                                .str.strip()
                                .str.replace(r"county(.+)coroner", r"county sheriff's office", regex=True)
    )
    return df 

dfa = read_npi()
dfa
# Out:
# /var/folders/r9/3_1rmy995xs_9z4vz66rsf9r0000gn/T/ipykernel_10672/3409637531.py:2: DtypeWarning: Columns (0,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/input/california_npi_output.csv")
#        person_nbr first_name middle_name       last_name  \
# 0         A52-V94     CARLOS     ALBERTO         IRIARTE
# 1         A52-V94     CARLOS     ALBERTO         IRIARTE
# 2         A52-V94     CARLOS     ALBERTO         IRIARTE
# 3         A52-V94     CARLOS     ALBERTO         IRIARTE
# 4         A52-V94     CARLOS     ALBERTO         IRIARTE
# ...           ...        ...         ...             ...
# 597888     293927      LUCIO         NaN  HERRERA ORTEGA
# 597889     293928       JOSE           F   DIAZ PENALOZA
# 597890     293928       JOSE           F   DIAZ PENALOZA
# 597891     293929   CRISTIAN           G          GAMBOA
# 597892     293929   CRISTIAN           G          GAMBOA
#
#                                               agency_name  start_date  \
# 0                                            SAN DIEGO PD  1984-09-21
# 1                                   LOS ANGELES SCHOOL PD  1988-12-12
# 2                                             LA PALMA PD  1994-09-22
# 3                                        REDONDO BEACH PD  1995-10-31
# 4                                           EL SEGUNDO PD  2009-10-05
# ...                                                   ...         ...
# 597888                      934: HIGH DESERT STATE PRISON  2019-04-01
# 597889  048: RA MCGEE CORR TRAIN CNTR -AKA- RICHARD A ...  2023-03-20
# 597890                      095: SAN QUENTIN STATE PRISON  2023-06-19
# 597891  048: RA MCGEE CORR TRAIN CNTR -AKA- RICHARD A ...  2019-10-15
# 597892                     674: CA. STATE PRISON - SOLANO  2020-01-27
#
#           end_date separation_reason
# 0       1984-10-05          Resigned
# 1       1995-10-28          Resigned
# 2       1995-09-27          Resigned
# 3       2009-10-04          Resigned
# 4       2010-01-30          Resigned
# ...            ...               ...
# 597888         NaN               NaN
# 597889         NaN               NaN
# 597890         NaN               NaN
# 597891         NaN               NaN
# 597892         NaN               NaN
#
# [597893 rows x 8 columns]

# %%
dfb = read_lear()

# %%
dfb = dfb.pipe(filter_state).pipe(fix_col_name).pipe(normalize_lear)

dfb
# Out:
#        LEAR_ID                        agency_name        STREET_ADDRESS  \
# 201     635867       pleasanton police department            PO BOX 909
# 202     635959      san leandro police department         901 E 14TH ST
# 203     635426      angels camp police department            PO BOX 459
# 204     635633          fortuna police department           621 11TH ST
# 205     635729     lassen county sheriff's office  1415 SHERIFF CADY LN
# ...        ...                                ...                   ...
# 15748   636130         woodland police department      1000 LINCOLN AVE
# 15749   636119  west sacramento police department     550 JEFFERSON AVE
# 15797   636139       yuba county sheriff's office           PO BOX 1389
# 15798   635770       marysville police department            PO BOX 670
# 15799   636121        wheatland police department           207 MAIN ST
#
#                   CITY    ZIP STATE COUNTY  FIPS  \
# 201         Pleasanton  94566    CA     -3  6001
# 202        San Leandro  94577    CA     -3  6001
# 203        Angels Camp  95222    CA     -3  6009
# 204            Fortuna  95540    CA     -3  6023
# 205         Susanville  96130    CA     -3  6035
# ...                ...    ...   ...    ...   ...
# 15748         Woodland  95695    CA   YOLO  6113
# 15749  West Sacramento  95605    CA   YOLO  6113
# 15797       Marysville  95901    CA   YUBA  6115
# 15798       Marysville  95901    CA   YUBA  6115
# 15799        WHEATLAND  95692    CA   YUBA  6115
#
#                              SOURCE  CSLLEA08_ID  ... PE14_MSA  \
# 201    CSLLEA14,POST,CSLLEA08,LEAIC     13430640  ...      783
# 202    CSLLEA14,POST,CSLLEA08,LEAIC     11489190  ...      783
# 203    CSLLEA14,POST,CSLLEA08,LEAIC     13083400  ...
# 204    CSLLEA14,POST,CSLLEA08,LEAIC     13297620  ...
# 205    CSLLEA14,POST,CSLLEA08,LEAIC     13984190  ...
# ...                             ...          ...  ...      ...
# 15748  CSLLEA14,POST,CSLLEA08,LEAIC     13599450  ...      740
# 15749  CSLLEA14,POST,CSLLEA08,LEAIC     13754470  ...      740
# 15797  CSLLEA14,POST,CSLLEA08,LEAIC     12809220  ...      990
# 15798  CSLLEA14,POST,CSLLEA08,LEAIC     13697060  ...      990
# 15799  CSLLEA14,POST,CSLLEA08,LEAIC     13365630  ...      990
#
#       PE14_POPULATION  PE14_MALE_OFFICERS PE14_MALE_CIVILIANS PE14_MALE_TOTAL  \
# 201             75060                  73                   4              77
# 202             88690                  87                   9              96
# 203              3716                   7                   0               7
# 204             11752                  13                   1              14
# 205             16657                  47                   7              54
# ...               ...                 ...                 ...             ...
# 15748           56854                  52                   0              52
# 15749           50152                  58                   3              61
# 15797           58227                 100                   9             109
# 15798           12242                  16                   4              20
# 15799            3521                   6                   0               6
#
#       PE14_FEMALE_OFFICERS PE14_FEMALE_CIVILIANS PE14_FEMALE_TOTAL  \
# 201                      8                    28                36
# 202                      6                    34                40
# 203                      0                     1                 1
# 204                      1                     7                 8
# 205                     14                    14                28
# ...                    ...                   ...               ...
# 15748                    9                    14                23
# 15749                    7                    18                25
# 15797                   25                    34                59
# 15798                    0                     5                 5
# 15799                    0                     1                 1
#
#       PE14_TOTAL_EMPLOYEES NO_POLICING
# 201                    113       False
# 202                    136       False
# 203                      8       False
# 204                     22       False
# 205                     82       False
# ...                    ...         ...
# 15748                   75       False
# 15749                   86       False
# 15797                  168       False
# 15798                   25       False
# 15799                    7       False
#
# [396 rows x 34 columns]

# %%
dfb_copy = dfb.copy()

dfb_copy = dfb_copy[dfb_copy.agency_name.str.contains(r"los angeles")]

dfb_copy.columns
# Out:
# Index(['LEAR_ID', 'agency_name', 'STREET_ADDRESS', 'CITY', 'ZIP', 'STATE',
#        'COUNTY', 'FIPS', 'SOURCE', 'CSLLEA08_ID', 'ORI9', 'ORI7', 'SAMPTYPE',
#        'LEAR_FULLTIME_SWORN', 'LEAR_PARTTIME_SWORN', 'CSLLEA08_FULLTIME_SWORN',
#        'CSLLEA08_PARTTIME_SWORN', 'CSLLEA08_FULLTIME_CIVILIAN',
#        'CSLLEA08_PARTTIME_CIVILIAN', 'LEMAS13_FULLTIME_SWORN',
#        'LEMAS13_PARTTIME_SWORN', 'LEMAS13_FULLTIME_CIVILIAN',
#        'LEMAS13_PARTTIME_CIVILIAN', 'PE14_DIVISION_REGION', 'PE14_MSA',
#        'PE14_POPULATION', 'PE14_MALE_OFFICERS', 'PE14_MALE_CIVILIANS',
#        'PE14_MALE_TOTAL', 'PE14_FEMALE_OFFICERS', 'PE14_FEMALE_CIVILIANS',
#        'PE14_FEMALE_TOTAL', 'PE14_TOTAL_EMPLOYEES', 'NO_POLICING'],
#       dtype='object')

# %%
dfa = dfa.pipe(normalize_npi)

df = pd.merge(dfa, dfb, on="agency_name")

df
# Out:
#        person_nbr first_name middle_name  last_name  \
# 0         A52-V94     CARLOS     ALBERTO    IRIARTE
# 1         A52-V94     CARLOS     ALBERTO    IRIARTE
# 2         A52-V94     CARLOS     ALBERTO    IRIARTE
# 3         A52-V94     CARLOS     ALBERTO    IRIARTE
# 4         B44-V58    MICHAEL           A   PUGLIESE
# ...           ...        ...         ...        ...
# 336652    A07-Q39      JAMES           J       MRAZ
# 336653    B82-Q06    RACHAEL       LICHT  VANSLOTEN
# 336654    B82-Q06    RACHAEL       LICHT  VANSLOTEN
# 336655    A91-J57     GEORGE      JOSEPH    MAHONEY
# 336656    A33-M29      SCOTT           R      PAGEL
#
#                               agency_name  start_date    end_date  \
# 0             san diego police department  1984-09-21  1984-10-05
# 1              la palma police department  1994-09-22  1995-09-27
# 2         redondo beach police department  1995-10-31  2009-10-04
# 3            el segundo police department  2009-10-05  2010-01-30
# 4       san mateo county sheriff's office  1973-02-01  2010-03-30
# ...                                   ...         ...         ...
# 336652      westminster police department  1983-02-04  2007-07-20
# 336653          oakland police department  1996-07-22  1997-01-31
# 336654          oakland police department  1997-01-31  2021-07-24
# 336655  san mateo county sheriff's office  1983-10-25  2005-12-29
# 336656        san diego police department  1995-01-20  1997-06-06
#
#          separation_reason  LEAR_ID         STREET_ADDRESS  ... PE14_MSA  \
# 0                 Resigned   635934          1401 BROADWAY  ...      777
# 1                 Resigned   635726         7792 WALKER ST  ...      478
# 2                 Resigned   635883             PO BOX 639  ...      480
# 3                 Resigned   635615            348 MAIN ST  ...      480
# 4                  Retired   635965         400 COUNTY CTR  ...      784
# ...                    ...      ...                    ...  ...      ...
# 336652             Retired   636117  8200 WESTMINSTER BLVD  ...      478
# 336653  Promotion/Demotion   635823             455 7TH ST  ...      783
# 336654             Retired   635823             455 7TH ST  ...      783
# 336655            Resigned   635965         400 COUNTY CTR  ...      784
# 336656            Resigned   635934          1401 BROADWAY  ...      777
#
#        PE14_POPULATION PE14_MALE_OFFICERS PE14_MALE_CIVILIANS PE14_MALE_TOTAL  \
# 0              1368690               1586                 228            1814
# 1                15977                 21                   0              21
# 2                68075                 82                  14              96
# 3                16990                 56                   5              61
# 4               138997                402                  57             459
# ...                ...                ...                 ...             ...
# 336652           92217                 80                   4              84
# 336653          409994                632                 115             747
# 336654          409994                632                 115             747
# 336655          138997                402                  57             459
# 336656         1368690               1586                 228            1814
#
#        PE14_FEMALE_OFFICERS  PE14_FEMALE_CIVILIANS PE14_FEMALE_TOTAL  \
# 0                       290                    416               706
# 1                         1                      8                 9
# 2                         8                     39                47
# 3                         4                     10                14
# 4                        60                    119               179
# ...                     ...                    ...               ...
# 336652                    9                     30                39
# 336653                   83                    264               347
# 336654                   83                    264               347
# 336655                   60                    119               179
# 336656                  290                    416               706
#
#        PE14_TOTAL_EMPLOYEES  NO_POLICING
# 0                      2520        False
# 1                        30        False
# 2                       143        False
# 3                        75        False
# 4                       638        False
# ...                     ...          ...
# 336652                  123        False
# 336653                 1094        False
# 336654                 1094        False
# 336655                  638        False
# 336656                 2520        False
#
# [336657 rows x 41 columns]

# %%
def read_cross():
    df = pd.read_excel("../data/input/post_crosswalk_for_review.xlsx")
    return df 

df_cross = read_cross()

df_cross
# Out:
#                        URSUS Agency Name Death Agency Number  \
# 0                                    NaN                 NaN
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                          ALAMEDA CO DA                 NaN
# 4    Alameda County Sheriff's Department               10000
# ..                                   ...                 ...
# 756              Yreka Police Department                 NaN
# 757          Yuba City Police Department              510200
# 758                                  NaN                 NaN
# 759            YUBA CO DISTRICT ATTORNEY                 NaN
# 760     Yuba County Sheriff's Department              580000
#
#                                  Primary Name Alternate URSUS Name        ORI  \
# 0                                         NaN                  NaN        NaN
# 1                                         NaN                  NaN        NaN
# 2                                         NaN                  NaN        NaN
# 3            Alameda County District Attorney                  NaN  CA001013A
# 4                      Alameda County Sheriff                  NaN  CA0010000
# ..                                        ...                  ...        ...
# 756                   Yreka Police Department                  NaN  CA0470900
# 757               Yuba City Police Department         YUBA CITY PD  CA0510200
# 758  Yuba Community College Police Department                  NaN        NaN
# 759             Yuba County District Attorney                  NaN  CA058013A
# 760                       Yuba County Sheriff                  NaN  CA0580000
#
#      NCIC  MuckRock Agency ID                       CRP pra Agency name  \
# 0     NaN                 NaN                                       NaN
# 1     NaN                 NaN                                       NaN
# 2     NaN                 NaN                                       NaN
# 3    6301              7895.0          Alameda County District Attorney
# 4     100               409.0                    Alameda County Sheriff
# ..    ...                 ...                                       ...
# 756  4709             19627.0                   Yreka Police Department
# 757  5102             19615.0               Yuba City Police Department
# 758  6606             19929.0  Yuba Community College Police Department
# 759  6358             18115.0             Yuba County District Attorney
# 760  5800             11165.0                       Yuba County Sheriff
#
#     Agency Type (string)                            resourceid    counties  \
# 0                    NaN                                   NaN  Unassigned
# 1                    NaN                                   NaN  Unassigned
# 2                    NaN                                   NaN     Alameda
# 3      District Attorney  1c86c693-cf29-4e67-acd0-ec564e2a0c24     Alameda
# 4                Sheriff  9bceb0c5-559a-42b0-b942-72101c467d56     Alameda
# ..                   ...                                   ...         ...
# 756    Police Department  397bdd2d-5cad-4058-ae86-2cc0b1efcee3    Siskiyou
# 757    Police Department  28bf7c61-aa70-486d-8cc5-194fb20e7050      Sutter
# 758    Community College  0b6491fc-235d-4cd3-9f02-d8060310abd2        Yuba
# 759    District Attorney  f4dac32d-e8df-409a-ad7b-4d6bcd3ca311        Yuba
# 760              Sheriff  21aa1083-d2c8-4d54-8e18-67c7eef2290b        Yuba
#
#                                post_name flag
# 0                            ADELANTO PD  NaN
# 1              ALAMEDA/CONTRA COSTA TRAN  NaN
# 2               ALAMEDA CO CORONER  C-01  NaN
# 3    ALAMEDA CO DA - INSPECTORS DIVISION  NaN
# 4                  ALAMEDA CO SD/CORONER  NaN
# ..                                   ...  ...
# 756                             YREKA PD  NaN
# 757                         YUBA CITY PD  NaN
# 758          YUBA COMMUNITY COLL DIST PD  NaN
# 759                           YUBA CO DA  NaN
# 760                           YUBA CO SD  NaN
#
# [761 rows x 13 columns]
